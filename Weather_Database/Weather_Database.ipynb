# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | natal
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | ilulissat
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | faanui
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | padang
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | rio gallegos
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | chilca
# Processing Record 18 of Set 1 | san jeronimo
# Processing Record 19 of Set 1 | airai
# Processing Record 20 of Set 1 | paamiut
# Processing Record 21 of Set 1 | coihaique
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | tumkur
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | lagos
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | lutz
# Processing Record 32 of Set 1 | half moon bay
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | luderitz
# Processing Record 35 of Set 1 | thinadhoo
# Processing Record 36 of Set 1 | zunyi
# Processing Record 37 of Set 1 | khandbari
# Processing Record 38 of Set 1 | krasnovishersk
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | seydi
# Processing Record 43 of Set 1 | houston
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | faya
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | port lincoln
# Processing Record 49 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 1 | naze
# Processing Record 1 of Set 2 | aklavik
# Processing Record 2 of Set 2 | aasiaat
# Processing Record 3 of Set 2 | karratha
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | vardo
# Processing Record 6 of Set 2 | kuala terengganu
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | bridge city
# Processing Record 9 of Set 2 | leshan
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | ambunti
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | alta gracia
# Processing Record 15 of Set 2 | shimoda
# Processing Record 16 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 17 of Set 2 | praia da vitoria
# Processing Record 18 of Set 2 | lipin bor
# Processing Record 19 of Set 2 | palmer
# Processing Record 20 of Set 2 | bad aibling
# Processing Record 21 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 2 | zhezkazgan
# Processing Record 23 of Set 2 | sinfra
# Processing Record 24 of Set 2 | nouadhibou
# Processing Record 25 of Set 2 | saint-dizier
# Processing Record 26 of Set 2 | rumoi
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | alofi
# Processing Record 29 of Set 2 | hays
# Processing Record 30 of Set 2 | hobe sound
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | sur
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | port augusta
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | namibe
# Processing Record 37 of Set 2 | balykshi
# Processing Record 38 of Set 2 | laguna de perlas
# Processing Record 39 of Set 2 | coahuayana
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | aswan
# Processing Record 42 of Set 2 | saint-pierre
# Processing Record 43 of Set 2 | batticaloa
# Processing Record 44 of Set 2 | ylivieska
# Processing Record 45 of Set 2 | samarai
# Processing Record 46 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | coos bay
# Processing Record 50 of Set 2 | haukipudas
# Processing Record 1 of Set 3 | keetmanshoop
# Processing Record 2 of Set 3 | aripuana
# Processing Record 3 of Set 3 | gejiu
# Processing Record 4 of Set 3 | lagoa
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | havoysund
# Processing Record 7 of Set 3 | carnarvon
# Processing Record 8 of Set 3 | bathsheba
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | graham
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | codrington
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | beringovskiy
# Processing Record 16 of Set 3 | san quintin
# Processing Record 17 of Set 3 | nikolayevsk-na-amure
# Processing Record 18 of Set 3 | mizpe ramon
# City not found. Skipping...
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 3 | maxixe
# Processing Record 22 of Set 3 | chapais
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | portland
# Processing Record 25 of Set 3 | namtsy
# Processing Record 26 of Set 3 | piterka
# Processing Record 27 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 28 of Set 3 | khomutovo
# Processing Record 29 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 3 | mazara del vallo
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | sao filipe
# Processing Record 33 of Set 3 | son la
# Processing Record 34 of Set 3 | bani walid
# Processing Record 35 of Set 3 | fukue
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | bandarbeyla
# Processing Record 38 of Set 3 | tamiahua
# Processing Record 39 of Set 3 | pontianak
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | garcia
# Processing Record 44 of Set 3 | katsuura
# Processing Record 45 of Set 3 | mikuni
# Processing Record 46 of Set 3 | lata
# Processing Record 47 of Set 3 | meulaboh
# Processing Record 48 of Set 3 | pochutla
# Processing Record 49 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 50 of Set 3 | svetlyy
# Processing Record 1 of Set 4 | pinega
# Processing Record 2 of Set 4 | rocha
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | ocean city
# Processing Record 6 of Set 4 | busselton
# Processing Record 7 of Set 4 | georgetown
# Processing Record 8 of Set 4 | langsa
# Processing Record 9 of Set 4 | yulara
# Processing Record 10 of Set 4 | alice springs
# Processing Record 11 of Set 4 | hasaki
# Processing Record 12 of Set 4 | baiao
# Processing Record 13 of Set 4 | abu kamal
# Processing Record 14 of Set 4 | adrar
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | sinjah
# City not found. Skipping...
# Processing Record 17 of Set 4 | chipata
# Processing Record 18 of Set 4 | poum
# Processing Record 19 of Set 4 | sitka
# Processing Record 20 of Set 4 | shingu
# Processing Record 21 of Set 4 | ponerihouen
# Processing Record 22 of Set 4 | yanam
# Processing Record 23 of Set 4 | honiara
# Processing Record 24 of Set 4 | nsanje
# Processing Record 25 of Set 4 | sao joao da barra
# Processing Record 26 of Set 4 | inhambane
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | quatre cocos
# Processing Record 29 of Set 4 | umm lajj
# Processing Record 30 of Set 4 | atbasar
# Processing Record 31 of Set 4 | porto walter
# Processing Record 32 of Set 4 | saskylakh
# Processing Record 33 of Set 4 | emerald
# Processing Record 34 of Set 4 | kalevala
# Processing Record 35 of Set 4 | husavik
# Processing Record 36 of Set 4 | tabou
# Processing Record 37 of Set 4 | udachnyy
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | san rafael
# Processing Record 41 of Set 4 | hofn
# City not found. Skipping...
# Processing Record 42 of Set 4 | teya
# Processing Record 43 of Set 4 | mawlaik
# Processing Record 44 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 4 | camocim
# Processing Record 46 of Set 4 | daru
# Processing Record 47 of Set 4 | melk
# Processing Record 48 of Set 4 | cabo san lucas
# Processing Record 49 of Set 4 | lorengau
# Processing Record 50 of Set 4 | chuy
# Processing Record 1 of Set 5 | margate
# Processing Record 2 of Set 5 | tsaratanana
# Processing Record 3 of Set 5 | serebryansk
# Processing Record 4 of Set 5 | beyneu
# Processing Record 5 of Set 5 | hostotipaquillo
# Processing Record 6 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 5 | khatanga
# Processing Record 9 of Set 5 | lillooet
# Processing Record 10 of Set 5 | khani
# Processing Record 11 of Set 5 | ocos
# Processing Record 12 of Set 5 | hervey bay
# Processing Record 13 of Set 5 | nam tha
# City not found. Skipping...
# Processing Record 14 of Set 5 | mehriz
# Processing Record 15 of Set 5 | dunda
# Processing Record 16 of Set 5 | oktyabrskiy
# Processing Record 17 of Set 5 | korla
# Processing Record 18 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 5 | panama city
# Processing Record 20 of Set 5 | trinidad
# Processing Record 21 of Set 5 | kirakira
# Processing Record 22 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 5 | rafai
# Processing Record 24 of Set 5 | ixtapa
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 5 | patacamaya
# Processing Record 28 of Set 5 | ossora
# Processing Record 29 of Set 5 | shpykiv
# City not found. Skipping...
# Processing Record 30 of Set 5 | pevek
# Processing Record 31 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 5 | pisco
# Processing Record 33 of Set 5 | xichang
# Processing Record 34 of Set 5 | buala
# Processing Record 35 of Set 5 | moshkovo
# Processing Record 36 of Set 5 | say
# Processing Record 37 of Set 5 | broken hill
# Processing Record 38 of Set 5 | kassala
# Processing Record 39 of Set 5 | kem
# Processing Record 40 of Set 5 | isangel
# Processing Record 41 of Set 5 | kavaratti
# Processing Record 42 of Set 5 | santiago
# Processing Record 43 of Set 5 | angoche
# Processing Record 44 of Set 5 | baghdad
# Processing Record 45 of Set 5 | dingle
# Processing Record 46 of Set 5 | saint anthony
# Processing Record 47 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | sterling
# Processing Record 49 of Set 5 | lerwick
# Processing Record 50 of Set 5 | khonsa
# Processing Record 1 of Set 6 | daund
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | esperance
# Processing Record 4 of Set 6 | yenotayevka
# Processing Record 5 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 6 of Set 6 | nyurba
# Processing Record 7 of Set 6 | ternate
# Processing Record 8 of Set 6 | hobart
# Processing Record 9 of Set 6 | kamenka
# Processing Record 10 of Set 6 | eureka
# Processing Record 11 of Set 6 | mehamn
# Processing Record 12 of Set 6 | tual
# Processing Record 13 of Set 6 | ambilobe
# Processing Record 14 of Set 6 | barguzin
# Processing Record 15 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 6 | nurota
# Processing Record 17 of Set 6 | wolfenbuttel
# Processing Record 18 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 6 | north myrtle beach
# Processing Record 20 of Set 6 | shumskiy
# Processing Record 21 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | kathu
# Processing Record 24 of Set 6 | solnechnyy
# Processing Record 25 of Set 6 | thung song
# Processing Record 26 of Set 6 | pacific grove
# Processing Record 27 of Set 6 | longyearbyen
# Processing Record 28 of Set 6 | akhmim
# Processing Record 29 of Set 6 | wanning
# Processing Record 30 of Set 6 | oranjemund
# Processing Record 31 of Set 6 | palmares do sul
# Processing Record 32 of Set 6 | mount gambier
# Processing Record 33 of Set 6 | havelock
# Processing Record 34 of Set 6 | tshikapa
# Processing Record 35 of Set 6 | fort nelson
# Processing Record 36 of Set 6 | nikolskoye
# Processing Record 37 of Set 6 | mayo
# Processing Record 38 of Set 6 | komsomolskiy
# Processing Record 39 of Set 6 | pahrump
# Processing Record 40 of Set 6 | kupang
# Processing Record 41 of Set 6 | cajabamba
# Processing Record 42 of Set 6 | pakwach
# City not found. Skipping...
# Processing Record 43 of Set 6 | kargil
# Processing Record 44 of Set 6 | sobolevo
# Processing Record 45 of Set 6 | villa carlos paz
# Processing Record 46 of Set 6 | mar del plata
# Processing Record 47 of Set 6 | berlevag
# Processing Record 48 of Set 6 | ghansor
# Processing Record 49 of Set 6 | la ronge
# Processing Record 50 of Set 6 | camacha
# Processing Record 1 of Set 7 | horadiz
# Processing Record 2 of Set 7 | westport
# Processing Record 3 of Set 7 | trofors
# Processing Record 4 of Set 7 | mitu
# Processing Record 5 of Set 7 | chinhoyi
# Processing Record 6 of Set 7 | bafra
# Processing Record 7 of Set 7 | aguimes
# Processing Record 8 of Set 7 | robertson
# Processing Record 9 of Set 7 | palana
# Processing Record 10 of Set 7 | taoudenni
# Processing Record 11 of Set 7 | zalantun
# Processing Record 12 of Set 7 | fairbanks
# Processing Record 13 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 7 | strezhevoy
# Processing Record 15 of Set 7 | coaldale
# Processing Record 16 of Set 7 | lusambo
# Processing Record 17 of Set 7 | atar
# Processing Record 18 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 7 | torzhok
# Processing Record 20 of Set 7 | ilo
# Processing Record 21 of Set 7 | baboua
# City not found. Skipping...
# Processing Record 22 of Set 7 | odesskoye
# Processing Record 23 of Set 7 | alekseyevsk
# Processing Record 24 of Set 7 | kroya
# Processing Record 25 of Set 7 | ginir
# Processing Record 26 of Set 7 | shubarkuduk
# Processing Record 27 of Set 7 | tahoua
# Processing Record 28 of Set 7 | ribeira grande
# Processing Record 29 of Set 7 | okhotsk
# Processing Record 30 of Set 7 | buchanan
# Processing Record 31 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 7 | alyangula
# Processing Record 33 of Set 7 | taki
# Processing Record 34 of Set 7 | ancud
# Processing Record 35 of Set 7 | tamworth
# Processing Record 36 of Set 7 | esmeraldas
# Processing Record 37 of Set 7 | tabukiniberu
# City not found. Skipping...
# Processing Record 38 of Set 7 | la rioja
# Processing Record 39 of Set 7 | cockburn town
# Processing Record 40 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 7 | umm kaddadah
# Processing Record 42 of Set 7 | damietta
# Processing Record 43 of Set 7 | bonthe
# Processing Record 44 of Set 7 | goderich
# Processing Record 45 of Set 7 | saint george
# Processing Record 46 of Set 7 | maarianhamina
# Processing Record 47 of Set 7 | wolkersdorf
# Processing Record 48 of Set 7 | vanimo
# Processing Record 49 of Set 7 | juneau
# Processing Record 50 of Set 7 | manyana
# Processing Record 1 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 2 of Set 8 | turochak
# Processing Record 3 of Set 8 | aksarka
# Processing Record 4 of Set 8 | rawson
# Processing Record 5 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 8 | masingbi
# Processing Record 7 of Set 8 | rancho palos verdes
# Processing Record 8 of Set 8 | vostok
# Processing Record 9 of Set 8 | pastavy
# Processing Record 10 of Set 8 | laguna
# Processing Record 11 of Set 8 | queanbeyan
# Processing Record 12 of Set 8 | launceston
# Processing Record 13 of Set 8 | arman
# Processing Record 14 of Set 8 | ati
# Processing Record 15 of Set 8 | kiunga
# Processing Record 16 of Set 8 | arroyo
# Processing Record 17 of Set 8 | bubaque
# Processing Record 18 of Set 8 | olga
# Processing Record 19 of Set 8 | shitanjing
# Processing Record 20 of Set 8 | sao felix do xingu
# Processing Record 21 of Set 8 | turukhansk
# Processing Record 22 of Set 8 | neyshabur
# Processing Record 23 of Set 8 | saint-augustin
# Processing Record 24 of Set 8 | sao jose da coroa grande
# Processing Record 25 of Set 8 | ahipara
# Processing Record 26 of Set 8 | mykolayivka
# Processing Record 27 of Set 8 | nosy varika
# Processing Record 28 of Set 8 | bara
# Processing Record 29 of Set 8 | aykhal
# Processing Record 30 of Set 8 | zhuhai
# Processing Record 31 of Set 8 | mecca
# Processing Record 32 of Set 8 | harper
# Processing Record 33 of Set 8 | humberto de campos
# Processing Record 34 of Set 8 | shu
# Processing Record 35 of Set 8 | letlhakane
# Processing Record 36 of Set 8 | monastyryshche
# Processing Record 37 of Set 8 | port shepstone
# Processing Record 38 of Set 8 | dikson
# Processing Record 39 of Set 8 | nantucket
# Processing Record 40 of Set 8 | olden
# Processing Record 41 of Set 8 | mandalgovi
# Processing Record 42 of Set 8 | sale
# Processing Record 43 of Set 8 | pokoynoye
# Processing Record 44 of Set 8 | namatanai
# Processing Record 45 of Set 8 | suhbaatar
# Processing Record 46 of Set 8 | san cristobal
# Processing Record 47 of Set 8 | atasu
# Processing Record 48 of Set 8 | itarema
# Processing Record 49 of Set 8 | cayenne
# Processing Record 50 of Set 8 | souillac
# Processing Record 1 of Set 9 | sola
# Processing Record 2 of Set 9 | kochi
# Processing Record 3 of Set 9 | vysokogornyy
# Processing Record 4 of Set 9 | cuiluan
# Processing Record 5 of Set 9 | honningsvag
# Processing Record 6 of Set 9 | qasigiannguit
# Processing Record 7 of Set 9 | ilhabela
# Processing Record 8 of Set 9 | ogulin
# Processing Record 9 of Set 9 | isla mujeres
# Processing Record 10 of Set 9 | pokhara
# Processing Record 11 of Set 9 | ukiah
# Processing Record 12 of Set 9 | conil
# Processing Record 13 of Set 9 | matara
# Processing Record 14 of Set 9 | corvallis
# Processing Record 15 of Set 9 | san patricio
# Processing Record 16 of Set 9 | te anau
# Processing Record 17 of Set 9 | zaysan
# Processing Record 18 of Set 9 | erenhot
# Processing Record 19 of Set 9 | vossevangen
# Processing Record 20 of Set 9 | fortuna
# Processing Record 21 of Set 9 | stulovo
# Processing Record 22 of Set 9 | dryden
# Processing Record 23 of Set 9 | muzhi
# Processing Record 24 of Set 9 | cap malheureux
# Processing Record 25 of Set 9 | constitucion
# Processing Record 26 of Set 9 | sayyan
# Processing Record 27 of Set 9 | touros
# Processing Record 28 of Set 9 | vila velha
# Processing Record 29 of Set 9 | gizo
# Processing Record 30 of Set 9 | gouyave
# Processing Record 31 of Set 9 | kruisfontein
# Processing Record 32 of Set 9 | floriano
# Processing Record 33 of Set 9 | tessalit
# Processing Record 34 of Set 9 | itaituba
# Processing Record 35 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 9 | tilichiki
# Processing Record 37 of Set 9 | noumea
# Processing Record 38 of Set 9 | vila franca do campo
# Processing Record 39 of Set 9 | tulun
# Processing Record 40 of Set 9 | dong hoi
# Processing Record 41 of Set 9 | mount isa
# Processing Record 42 of Set 9 | alghero
# Processing Record 43 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 9 | moroto
# Processing Record 45 of Set 9 | rio grande
# Processing Record 46 of Set 9 | cislau
# Processing Record 47 of Set 9 | booue
# Processing Record 48 of Set 9 | nkhata bay
# Processing Record 49 of Set 9 | vincennes
# Processing Record 50 of Set 9 | lumphat
# Processing Record 1 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 2 of Set 10 | lewiston
# Processing Record 3 of Set 10 | yar-sale
# Processing Record 4 of Set 10 | belaya gora
# Processing Record 5 of Set 10 | pyaozerskiy
# Processing Record 6 of Set 10 | westerlo
# Processing Record 7 of Set 10 | lavrentiya
# Processing Record 8 of Set 10 | soligalich
# Processing Record 9 of Set 10 | tasiilaq
# Processing Record 10 of Set 10 | hualmay
# Processing Record 11 of Set 10 | kazuno
# Processing Record 12 of Set 10 | nacogdoches
# Processing Record 13 of Set 10 | pangnirtung
# Processing Record 14 of Set 10 | gari
# Processing Record 15 of Set 10 | mildura
# Processing Record 16 of Set 10 | joshimath
# Processing Record 17 of Set 10 | mookane
# Processing Record 18 of Set 10 | myitkyina
# Processing Record 19 of Set 10 | kawalu
# Processing Record 20 of Set 10 | raga
# Processing Record 21 of Set 10 | asau
# Processing Record 22 of Set 10 | meihekou
# Processing Record 23 of Set 10 | port pirie
# Processing Record 24 of Set 10 | luis correia
# Processing Record 25 of Set 10 | onega
# Processing Record 26 of Set 10 | caravelas
# Processing Record 27 of Set 10 | cherskiy
# Processing Record 28 of Set 10 | ondangwa
# Processing Record 29 of Set 10 | puerto ayacucho
# Processing Record 30 of Set 10 | kotka
# Processing Record 31 of Set 10 | luganville
# Processing Record 32 of Set 10 | rio cauto
# Processing Record 33 of Set 10 | kropotkin
# Processing Record 34 of Set 10 | taphan hin
# Processing Record 35 of Set 10 | kurilsk
# Processing Record 36 of Set 10 | manakara
# Processing Record 37 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 38 of Set 10 | punta alta
# Processing Record 39 of Set 10 | mezhdurechensk
# Processing Record 40 of Set 10 | jiuquan
# Processing Record 41 of Set 10 | fort-shevchenko
# Processing Record 42 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 10 | general roca
# Processing Record 44 of Set 10 | hamilton
# Processing Record 45 of Set 10 | chama
# Processing Record 46 of Set 10 | sambava
# Processing Record 47 of Set 10 | flinders
# Processing Record 48 of Set 10 | esso
# Processing Record 49 of Set 10 | oriximina
# Processing Record 50 of Set 10 | pangody
# Processing Record 1 of Set 11 | victor harbor
# Processing Record 2 of Set 11 | farmington
# Processing Record 3 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 11 | haimen
# Processing Record 5 of Set 11 | we
# City not found. Skipping...
# Processing Record 6 of Set 11 | himora
# City not found. Skipping...
# Processing Record 7 of Set 11 | nelson bay
# Processing Record 8 of Set 11 | mackay
# Processing Record 9 of Set 11 | gavle
# Processing Record 10 of Set 11 | banda aceh
# Processing Record 11 of Set 11 | gushikawa
# Processing Record 12 of Set 11 | ilebo
# Processing Record 13 of Set 11 | palpa
# Processing Record 14 of Set 11 | dongsheng
# Processing Record 15 of Set 11 | hokitika
# Processing Record 16 of Set 11 | vestmannaeyjar
# Processing Record 17 of Set 11 | shakiso
# Processing Record 18 of Set 11 | nioki
# Processing Record 19 of Set 11 | tarauaca
# Processing Record 20 of Set 11 | kralendijk
# Processing Record 21 of Set 11 | barinas
# Processing Record 22 of Set 11 | krasnyy yar
# Processing Record 23 of Set 11 | bilma
# Processing Record 24 of Set 11 | kaitangata
# Processing Record 25 of Set 11 | selizharovo
# Processing Record 26 of Set 11 | melo
# Processing Record 27 of Set 11 | kastamonu
# Processing Record 28 of Set 11 | carutapera
# Processing Record 29 of Set 11 | anadyr
# Processing Record 30 of Set 11 | santa maria
# Processing Record 31 of Set 11 | sicamous
# Processing Record 32 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 11 | santa rosalia
# Processing Record 34 of Set 11 | tigil
# Processing Record 35 of Set 11 | pajapita
# Processing Record 36 of Set 11 | woodward
# Processing Record 37 of Set 11 | tigzirt
# Processing Record 38 of Set 11 | am timan
# Processing Record 39 of Set 11 | shetpe
# Processing Record 40 of Set 11 | camalu
# Processing Record 41 of Set 11 | koygorodok
# Processing Record 42 of Set 11 | batagay-alyta
# Processing Record 43 of Set 11 | ji-parana
# City not found. Skipping...
# Processing Record 44 of Set 11 | chara
# Processing Record 45 of Set 11 | vanavara
# Processing Record 46 of Set 11 | grand gaube
# Processing Record 47 of Set 11 | wum
# Processing Record 48 of Set 11 | borger
# Processing Record 49 of Set 11 | brae
# Processing Record 50 of Set 11 | middletown
# Processing Record 1 of Set 12 | salalah
# Processing Record 2 of Set 12 | santa cruz
# Processing Record 3 of Set 12 | maldonado
# Processing Record 4 of Set 12 | huarmey
# Processing Record 5 of Set 12 | kieta
# Processing Record 6 of Set 12 | nome
# Processing Record 7 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 12 | varzea da palma
# Processing Record 9 of Set 12 | port blair
# Processing Record 10 of Set 12 | redmond
# Processing Record 11 of Set 12 | cabedelo
# Processing Record 12 of Set 12 | karakulino
# Processing Record 13 of Set 12 | forrest city
# Processing Record 14 of Set 12 | nisia floresta
# Processing Record 15 of Set 12 | dzhebariki-khaya
# Processing Record 16 of Set 12 | vaitape
# Processing Record 17 of Set 12 | whitehorse
# Processing Record 18 of Set 12 | santa isabel do rio negro
# Processing Record 19 of Set 12 | port hardy
# Processing Record 20 of Set 12 | mbuji-mayi
# Processing Record 21 of Set 12 | marawi
# Processing Record 22 of Set 12 | linhares
# Processing Record 23 of Set 12 | dekar
# Processing Record 24 of Set 12 | henties bay
# Processing Record 25 of Set 12 | antalaha
# Processing Record 26 of Set 12 | evensk
# Processing Record 27 of Set 12 | talara
# Processing Record 28 of Set 12 | olafsvik
# Processing Record 29 of Set 12 | pointe michel
# Processing Record 30 of Set 12 | torbay
# Processing Record 31 of Set 12 | avera
# Processing Record 32 of Set 12 | marsa matruh
# Processing Record 33 of Set 12 | ashington
# Processing Record 34 of Set 12 | ziway
# Processing Record 35 of Set 12 | bilibino
# Processing Record 36 of Set 12 | eyl
# Processing Record 37 of Set 12 | kidal
# Processing Record 38 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 39 of Set 12 | chuzhou
# Processing Record 40 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 12 | reporoa
# Processing Record 42 of Set 12 | demyansk
# Processing Record 43 of Set 12 | kahului
# Processing Record 44 of Set 12 | masallatah
# Processing Record 45 of Set 12 | wakkanai
# Processing Record 46 of Set 12 | smithers
# Processing Record 47 of Set 12 | salaga
# Processing Record 48 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 49 of Set 12 | chifeng
# Processing Record 50 of Set 12 | saldanha
# Processing Record 1 of Set 13 | hirara
# Processing Record 2 of Set 13 | kovdor
# Processing Record 3 of Set 13 | busayra
# Processing Record 4 of Set 13 | vicksburg
# Processing Record 5 of Set 13 | duluth
# Processing Record 6 of Set 13 | barcanesti
# Processing Record 7 of Set 13 | north bend
# Processing Record 8 of Set 13 | narasannapeta
# Processing Record 9 of Set 13 | takoradi
# Processing Record 10 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 13 | denpasar
# Processing Record 12 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 13 | longyan
# Processing Record 14 of Set 13 | los llanos de aridane
# Processing Record 15 of Set 13 | coquimbo
# Processing Record 16 of Set 13 | bambous virieux
# Processing Record 17 of Set 13 | rosarito
# Processing Record 18 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 19 of Set 13 | dzilam gonzalez
# Processing Record 20 of Set 13 | pirai do sul
# Processing Record 21 of Set 13 | devils lake
# Processing Record 22 of Set 13 | ulaangom
# Processing Record 23 of Set 13 | upata
# Processing Record 24 of Set 13 | riyadh
# Processing Record 25 of Set 13 | kaeo
# Processing Record 26 of Set 13 | pecangakan
# Processing Record 27 of Set 13 | montepuez
# Processing Record 28 of Set 13 | salinopolis
# Processing Record 29 of Set 13 | champerico
# Processing Record 30 of Set 13 | pandan
# Processing Record 31 of Set 13 | grenfell
# Processing Record 32 of Set 13 | sibolga
# Processing Record 33 of Set 13 | bondowoso
# Processing Record 34 of Set 13 | kovur
# Processing Record 35 of Set 13 | alexandria
# Processing Record 36 of Set 13 | griffith
# Processing Record 37 of Set 13 | stromness
# Processing Record 38 of Set 13 | omsukchan
# Processing Record 39 of Set 13 | marovoay
# Processing Record 40 of Set 13 | torit
# Processing Record 41 of Set 13 | neiafu
# Processing Record 42 of Set 13 | lahij
# Processing Record 43 of Set 13 | heihe
# Processing Record 44 of Set 13 | guerrero negro
# Processing Record 45 of Set 13 | makakilo city
# Processing Record 46 of Set 13 | nemuro
# Processing Record 47 of Set 13 | rorvik
# Processing Record 48 of Set 13 | virginia beach
# Processing Record 49 of Set 13 | arkul
# Processing Record 50 of Set 13 | tacuarembo
# Processing Record 1 of Set 14 | ozernovskiy
# Processing Record 2 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 14 | motema
# Processing Record 5 of Set 14 | gainsborough
# Processing Record 6 of Set 14 | batemans bay
# Processing Record 7 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 8 of Set 14 | gympie
# Processing Record 9 of Set 14 | qiongshan
# Processing Record 10 of Set 14 | buraydah
# Processing Record 11 of Set 14 | leeton
# Processing Record 12 of Set 14 | biak
# Processing Record 13 of Set 14 | tianpeng
# Processing Record 14 of Set 14 | sembe
# Processing Record 15 of Set 14 | kangalassy
# Processing Record 16 of Set 14 | iqaluit
# Processing Record 17 of Set 14 | nizhnevartovsk
# Processing Record 18 of Set 14 | barentu
# Processing Record 19 of Set 14 | andrelandia
# Processing Record 20 of Set 14 | morant bay
# Processing Record 21 of Set 14 | high level
# Processing Record 22 of Set 14 | serta
# Processing Record 23 of Set 14 | viesca
# Processing Record 24 of Set 14 | envira
# Processing Record 25 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 26 of Set 14 | miraflores
# Processing Record 27 of Set 14 | turayf
# Processing Record 28 of Set 14 | fenoarivo
# Processing Record 29 of Set 14 | tres arroyos
# Processing Record 30 of Set 14 | panguna
# Processing Record 31 of Set 14 | sitio novo do tocantins
# Processing Record 32 of Set 14 | keuruu
# Processing Record 33 of Set 14 | nuuk
# Processing Record 34 of Set 14 | tazovskiy
# Processing Record 35 of Set 14 | sumbe
# Processing Record 36 of Set 14 | sabang
# Processing Record 37 of Set 14 | usogorsk
# Processing Record 38 of Set 14 | khorixas
# Processing Record 39 of Set 14 | dubbo
# Processing Record 40 of Set 14 | jieshi
# Processing Record 41 of Set 14 | petropavlovskoye
# Processing Record 42 of Set 14 | santa cruz de tenerife
# Processing Record 43 of Set 14 | chiusi
# Processing Record 44 of Set 14 | acajutla
# Processing Record 45 of Set 14 | koboko
# Processing Record 46 of Set 14 | sosnovo-ozerskoye
# Processing Record 47 of Set 14 | piacabucu
# Processing Record 48 of Set 14 | ryotsu
# Processing Record 49 of Set 14 | xinzhi
# Processing Record 50 of Set 14 | americus
# Processing Record 1 of Set 15 | hue
# Processing Record 2 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 3 of Set 15 | nishihara
# Processing Record 4 of Set 15 | gat
# Processing Record 5 of Set 15 | kulhudhuffushi
# Processing Record 6 of Set 15 | matamoros
# Processing Record 7 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 15 | batagay
# Processing Record 9 of Set 15 | banjarmasin
# Processing Record 10 of Set 15 | kyotera
# Processing Record 11 of Set 15 | puerto del rosario
# Processing Record 12 of Set 15 | lasa
# Processing Record 13 of Set 15 | saint-georges
# Processing Record 14 of Set 15 | shangzhi
# Processing Record 15 of Set 15 | basqal
# Processing Record 16 of Set 15 | usinsk
# Processing Record 17 of Set 15 | lompoc
# Processing Record 18 of Set 15 | edgewater
# Processing Record 19 of Set 15 | dawlatabad
# Processing Record 20 of Set 15 | boende
# Processing Record 21 of Set 15 | baruun-urt
# Processing Record 22 of Set 15 | cotacachi
# Processing Record 23 of Set 15 | santa marinella
# Processing Record 24 of Set 15 | bemidji
# Processing Record 25 of Set 15 | skelleftea
# Processing Record 26 of Set 15 | kloulklubed
# Processing Record 27 of Set 15 | patan
# Processing Record 28 of Set 15 | awbari
# Processing Record 29 of Set 15 | alibag
# Processing Record 30 of Set 15 | winnemucca
# Processing Record 31 of Set 15 | phibun mangsahan
# Processing Record 32 of Set 15 | voyvozh
# Processing Record 33 of Set 15 | kyabram
# Processing Record 34 of Set 15 | mbaiki
# Processing Record 35 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 15 | fairhope
# Processing Record 37 of Set 15 | san juan
# Processing Record 38 of Set 15 | kemijarvi
# Processing Record 39 of Set 15 | zhenlai
# Processing Record 40 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 15 | sept-iles
# Processing Record 42 of Set 15 | bosaso
# Processing Record 43 of Set 15 | cortes
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 680

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     New Norfolk -42.7826  147.0587     60.30        85         100
# 1           Natal  -5.7950  -35.2094     79.45        83          75
# 2  Severo-Kurilsk  50.6789  156.1250     38.95        66          57
# 3     Port Alfred -33.5906   26.8910     66.18        97          61
# 4       Ilulissat  69.2167  -51.1000     27.27        97         100
# 5          Faanui -16.4833 -151.7500     79.83        77         100
# 6          Kodiak  57.7900 -152.4072     44.11        57           0
# 7       Mahebourg -20.4081   57.7000     77.29        65          40
# 8          Bethel  41.3712  -73.4140     61.48        89         100
# 9           Vaini -21.2000 -175.2000     73.56        60          75
#
#    Wind Speed Country       Description
# 0        1.01      AU     moderate rain
# 1       10.36      BR     broken clouds
# 2       17.11      RU        light rain
# 3        5.01      ZA        light rain
# 4        4.43      GL        light snow
# 5       17.85      PF   overcast clouds
# 6        4.61      US         clear sky
# 7       11.50      MU  scattered clouds
# 8        3.44      US              mist
# 9       10.36      TO     broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     New Norfolk      AU -42.7826  147.0587     60.30        85         100
# 1           Natal      BR  -5.7950  -35.2094     79.45        83          75
# 2  Severo-Kurilsk      RU  50.6789  156.1250     38.95        66          57
# 3     Port Alfred      ZA -33.5906   26.8910     66.18        97          61
# 4       Ilulissat      GL  69.2167  -51.1000     27.27        97         100
# 5          Faanui      PF -16.4833 -151.7500     79.83        77         100
# 6          Kodiak      US  57.7900 -152.4072     44.11        57           0
# 7       Mahebourg      MU -20.4081   57.7000     77.29        65          40
# 8          Bethel      US  41.3712  -73.4140     61.48        89         100
# 9           Vaini      TO -21.2000 -175.2000     73.56        60          75
#
#    Wind Speed       Description
# 0        1.01     moderate rain
# 1       10.36     broken clouds
# 2       17.11        light rain
# 3        5.01        light rain
# 4        4.43        light snow
# 5       17.85   overcast clouds
# 6        4.61         clear sky
# 7       11.50  scattered clouds
# 8        3.44              mist
# 9       10.36     broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
